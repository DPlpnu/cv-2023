# %% [markdown]
# ## Download COCO-2017 dataset

# %% [markdown]
# ### Install required libraries

# %%
# !pip install fiftyone
# !pip install bash_kernel
# !python -m bash_kernel.install
# !pip install tensorflow tensorflow-datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 16.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.8/226.8 kB 17.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.6/135.6 kB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 12.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 492.1/492.1 kB 44.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.8/37.8 MB 24.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.9/68.9 kB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.5/192.5 kB 22.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 568.2/568.2 kB 47.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### Download dataset

# %%
# !fiftyone zoo datasets download coco-2017 --dataset-dir
# Out:
# Migrating database to v0.20.1
# usage: fiftyone zoo datasets download
#        [-h]
#        [-s SPLITS [SPLITS ...]]
#        [-d DATASET_DIR]
#        [-k KEY=VAL [KEY=VAL ...]]
#        NAME
# fiftyone zoo datasets download: error: argument -d/--dataset-dir: expected one argument

# %% [markdown]
# ### Dataset info

# %%
# !fiftyone zoo datasets info coco-2017
# Out:
# Migrating database to v0.20.1
# ***** Dataset description *****
# COCO is a large-scale object detection, segmentation, and captioning
# dataset.
#
# This version contains images, bounding boxes, segmentations, and keypoints
# for the 2017 version of the dataset.
#
# This dataset supports partial downloads:
#
# -   You can specify subsets of data to download via the ``label_types``,
#     ``classes``, and ``max_samples`` parameters
# -   You can specify specific images to load via the ``image_ids`` parameter
#
# See :ref:`this page <dataset-zoo-coco-2017>` for more information about
# partial downloads of this dataset.
#
# Full split stats:
#
# -   Train split: 118,287 images
# -   Test split: 40,670 images
# -   Validation split: 5,000 images
#
# Notes:
#
# -   COCO defines 91 classes but the data only uses 80 classes
# -   Some images from the train and validation sets don't have annotations
# -   The test set does not have annotations
# ...

# %% [markdown]
# ### Convert dataset to YOLO format

# %%
# !fiftyone convert \
    --input-dir $(fiftyone zoo datasets find coco-2017) --input-type fiftyone.types.FiftyOneImageClassificationDataset \
    --output-dir /content/drive/MyDrive/CV/Lab4/Yolo_training/yolov5/yolo_dataset --output-type fiftyone.types.YOLOv5Dataset
# Out:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/fiftyone/zoo/datasets/__init__.py", line 383, in find_zoo_dataset
#     zoo_dataset.load_info(dataset_dir)
#   File "/usr/local/lib/python3.9/dist-packages/fiftyone/zoo/datasets/__init__.py", line 962, in load_info
#     return ZooDatasetInfo.from_json(
#   File "/usr/local/lib/python3.9/dist-packages/fiftyone/zoo/datasets/__init__.py", line 748, in from_json
#     d = etas.read_json(json_path)
#   File "/usr/local/lib/python3.9/dist-packages/eta/core/serial.py", line 106, in read_json
#     with open(path, "rt") as f:
# FileNotFoundError: [Errno 2] No such file or directory: '/root/fiftyone/coco-2017/info.json'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/bin/fiftyone", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.9/dist-packages/fiftyone/core/cli.py", line 3246, in main
# ...

# %% [markdown]
# ## YOLO model

# %% [markdown]
# ### Change working directory (yolo folder)

# %%
import os
from google.colab import drive
drive.mount('/content/drive/')

os.chdir('/content/drive/MyDrive/CV/Lab4/Yolo_training/yolov5')
os.getcwd()
# Out:
# Mounted at /content/drive/
# '/content/drive/MyDrive/CV/Lab4/Yolo_training/yolov5'

# %% [markdown]
# ### Install all required packages from requirements.txt

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### Training YOLO Model

# %%
# !python train.py --data data.yaml --weights yolov5s.pt --img 640 --batch-size 8 --name Model_25 --epochs 25
# Out:
# 2023-04-20 21:40:18.795527: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-20 21:40:19.959521: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %% [markdown]
# ### Resume training (optional)

# %%
# Resume the model training
# !python train.py --data data.yaml --weights runs/train/Model_res2/weights/best.pt --img 640 --batch-size 8 --name Model_res_last --epochs 25 --cache
# Out:
# 2023-04-21 05:35:58.879448: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-21 05:35:59.988523: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %% [markdown]
# ## Export Model into onnx file

# %%
# !python export.py --weights runs/train/Model_res_last/weights/best.pt --include onnx --simplify --opset 12
# Out:
# export: data=data/coco128.yaml, weights=['runs/train/Model_res_last/weights/best.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=12, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['onnx']
# YOLOv5 🚀 v7.0-120-g3e55763 Python-3.9.16 torch-2.0.0+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
#
# PyTorch: starting from runs/train/Model_res_last/weights/best.pt with output shape (1, 25200, 25) (13.8 MB)
# requirements: YOLOv5 requirement "onnx>=1.12.0" not found, attempting AutoUpdate...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 79.6 MB/s eta 0:00:00
# ...
#
# requirements: 1 package updated per ['onnx>=1.12.0']
# ...

# %% [markdown]
# ## Model evaluation

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# ### Define varibles, functions, packages

# %%
import cv2
import matplotlib.pyplot as plt
from yolo_predictions import YOLO_Pred

# %%
yaml_file = '/content/drive/MyDrive/CV/Lab4/Yolo_training/yolov5/data.yaml'
onnx_file = '/content/drive/MyDrive/CV/Lab4/Yolo_training/yolov5/runs/train/Model_res_last/weights/best.onnx'

image_1 = cv2.imread('/content/drive/MyDrive/CV/Lab4/Yolo_training/img3.jpg')

# %%
def show_img(image):
  plt.figure(figsize=(25, 20))
  plt.imshow(image)
  plt.title("Test Image")
  plt.show()

# %% [markdown]
# ### Create predictions

# %%
yolo = YOLO_Pred(onnx_file, yaml_file)

img_pred = yolo.predictions(image_1)

# %% [markdown]
# ### Test model on image

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img_pred)
# Out:
# <PIL.Image.Image image mode=RGB size=1080x720 at 0x7FD8454290A0>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
from PIL import Image

model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
model.eval()

image = Image.open('/content/drive/MyDrive/photos/lviv1.jpg')
results = model([image])

# Display the detected objects and their confidence scores
results.show()
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2023-4-21 Python-3.9.16 torch-2.0.0+cu118 CPU
# requirements: /root/.cache/torch/hub/requirements.txt not found, check failed.
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5s.pt...
# 100%|██████████| 14.1M/14.1M [00:00<00:00, 17.5MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...
# <PIL.Image.Image image mode=RGB size=1536x1024 at 0x7F20A2BDA730>

# %%
results.print()
# Out:
# image 1/1: 1024x1536 21 persons, 2 umbrellas
# Speed: 90.2ms pre-process, 400.6ms inference, 22.8ms NMS per image at shape (1, 3, 448, 640)

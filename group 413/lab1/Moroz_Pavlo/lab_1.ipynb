# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
K = 1
L = 0

# %%
def change(image,k = 1,l = 0):
    new_image = np.zeros(image.shape,dtype=int)
    for i in range(image.shape[0]):
        for j in range(image.shape[1]):
            for c in range(image.shape[2]):
                new_image[i][j][c] = max(min(255,int(k*image[i][j][c]) + l),0)
                pass
    return  new_image

# %%
image_name = "low_contrast.jpeg"
image = np.asarray(Image.open(image_name))
imgplot = plt.imshow(image)

# %%
image = np.asarray(Image.open(image_name))
new_image = change(image,1.5,l = 0)
imgplot = plt.imshow(new_image)

# %%
image_name = "high-constrant.JPG"
image = np.asarray(Image.open(image_name))
imgplot = plt.imshow(image)

# %%
image = np.asarray(Image.open(image_name))
new_image = change(image,1.5,l = 0)
imgplot = plt.imshow(new_image)

# %%
image_name = "high_detail.jpg"
image = np.asarray(Image.open(image_name))
imgplot = plt.imshow(image)

# %%
image = np.asarray(Image.open(image_name))
new_image = change(image,3,l = 4)
imgplot = plt.imshow(new_image)

# %%
image_name = "low_detail.jpeg.webp"
image = np.asarray(Image.open(image_name))
imgplot = plt.imshow(image)

# %%
image = np.asarray(Image.open(image_name))
new_image = change(image, 1.5, l=0)
imgplot = plt.imshow(new_image)

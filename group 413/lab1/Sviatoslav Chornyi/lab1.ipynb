# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
def gamma_correction(src, gamma):
    hist_gamma = 1 / gamma

    table = [((i / 255) ** hist_gamma) * 255 for i in range(256)]
    table = np.array(table, np.uint8)

    return cv2.LUT(src, table)

# %%
def showFilter(img, k):
    plt.imshow(img)
    plt.axis('off')
    plt.title("Left shifk with k = " + str(k))
    plt.show()

# %%
def showCommon(img):
    plt.imshow(img)
    plt.axis('off')
    plt.title("Default image")
    plt.show()

# %%
imgContrast = cv2.cvtColor(cv2.imread('images/high_contrast.jpg'), cv2.COLOR_BGR2RGB)
imgShadow = cv2.cvtColor(cv2.imread('images/high_detailed.jpg'), cv2.COLOR_BGR2RGB)
imgLight = cv2.cvtColor(cv2.imread('images/low_detailed.jpg'), cv2.COLOR_BGR2RGB)

# %%
showCommon(imgContrast)
shift = gamma_correction(imgContrast, 0.4)
showFilter(shift, 0.4)

# %%
showCommon(imgShadow)
shift = gamma_correction(imgShadow, 0.4)
showFilter(shift, 0.4)

# %%
showCommon(imgLight)
shift = gamma_correction(imgLight, 0.4)
showFilter(shift, 0.4)

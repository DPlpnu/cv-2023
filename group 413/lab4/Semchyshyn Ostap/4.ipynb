# %% [markdown]
# ## YOLOv3

# %%
from gluoncv import model_zoo, data, utils
from matplotlib import pyplot as plt

# %%
net = model_zoo.get_model('yolo3_darknet53_voc', pretrained=True)

# %%
img1 = utils.download('https://files.libertycity.ru/download/skins_gtasastyle/fulls/lvu00vseo13iu4v6rjvt54bb94/15669262098366_8wcntmp_ahe.jpg', path='15669262098366_8wcntmp_ahe.jpg')
img2 = utils.download('https://i.ytimg.com/vi/kofvWWC_j10/hqdefault.jpg', path='hqdefault.jpg')
img3 = utils.download('https://pbs.twimg.com/media/C_LF-iwVYAEgOHN.jpg', path='C_LF-iwVYAEgOHN.jpg')
# Out:
# Downloading 15669262098366_8wcntmp_ahe.jpg from https://files.libertycity.ru/download/skins_gtasastyle/fulls/lvu00vseo13iu4v6rjvt54bb94/15669262098366_8wcntmp_ahe.jpg...
# 44KB [00:00, 5429.52KB/s]

# %%
x1, image1 = data.transforms.presets.ssd.load_test(img1, short=512)
x2, image2 = data.transforms.presets.ssd.load_test(img2, short=512)
x3, image3 = data.transforms.presets.ssd.load_test(img3, short=512)

# %%
class_IDs, scores, bounding_boxes = net(x1)
plt.imshow(image1)
ax = utils.viz.plot_bbox(image1, bounding_boxes[0], scores[0],
                         class_IDs[0], class_names=net.classes)
plt.show()

# %%
class_IDs, scores, bounding_boxes = net(x2)
plt.imshow(image2)
ax = utils.viz.plot_bbox(image2, bounding_boxes[0], scores[0],
                         class_IDs[0], class_names=net.classes)
plt.show()

# %%
class_IDs, scores, bounding_boxes = net(x3)
plt.imshow(image3)
ax = utils.viz.plot_bbox(image3, bounding_boxes[0], scores[0],
                         class_IDs[0], class_names=net.classes)
plt.show()
